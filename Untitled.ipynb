# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp

# %%
import os;

# %%
pwd
# Out:
# 'C:\\Users\\Samhith Reddy\\Missing data'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 924B-45CA
#
#  Directory of C:\Users\Samhith Reddy\Missing data
#
# 02/10/2023  10:50 PM    <DIR>          .
# 02/10/2023  09:51 PM    <DIR>          ..
# 02/10/2023  09:52 PM    <DIR>          .ipynb_checkpoints
# 02/06/2023  10:51 PM           911,261 parkinsons_updrs.csv.csv
# 02/10/2023  10:43 PM             1,361 Untitled.ipynb
#                2 File(s)        912,622 bytes
#                3 Dir(s)  128,602,234,880 bytes free

# %%
missingdata=pd.read_csv('parkinsons_updrs.csv.csv')
test = pd.read_csv('test.csv')

missingdata.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
import pandas as pd

# %%
missingdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %%
missingdata.isnull().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
len(missingdata)
# Out:
# 5875

# %%
missingdata.isnull().sum()/len(missingdata)
# Out:
# subject#         0.0
# age              0.0
# sex              0.0
# test_time        0.0
# motor_UPDRS      0.0
# total_UPDRS      0.0
# Jitter(%)        0.0
# Jitter(Abs)      0.0
# Jitter:RAP       0.0
# Jitter:PPQ5      0.0
# Jitter:DDP       0.0
# Shimmer          0.0
# Shimmer(dB)      0.0
# Shimmer:APQ3     0.0
# Shimmer:APQ5     0.0
# Shimmer:APQ11    0.0
# Shimmer:DDA      0.0
# NHR              0.0
# HNR              0.0
# RPDE             0.0
# DFA              0.0
# PPE              0.0
# dtype: float64

# %%
y = missingdata['DFA']
X = missingdata.drop(['DFA','age'], axis = 1)

# %%
y.value_counts()
# Out:
# 0.58900    4
# 0.64624    4
# 0.58845    4
# 0.57965    4
# 0.59545    4
#           ..
# 0.59404    1
# 0.56690    1
# 0.58736    1
# 0.53084    1
# 0.57077    1
# Name: DFA, Length: 5282, dtype: int64

# %%
X.head()
# Out:
#    subject#  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  Jitter(Abs)  \
# 0         1    0     5.6431       28.199       34.398    0.00662     0.000034
# 1         1    0    12.6660       28.447       34.894    0.00300     0.000017
# 2         1    0    19.6810       28.695       35.389    0.00481     0.000025
# 3         1    0    25.6470       28.905       35.810    0.00528     0.000027
# 4         1    0    33.6420       29.187       36.375    0.00335     0.000020
#
#    Jitter:RAP  Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.00401      0.00317     0.01204  0.02565        0.230       0.01438
# 1     0.00132      0.00150     0.00395  0.02024        0.179       0.00994
# 2     0.00205      0.00208     0.00616  0.01675        0.181       0.00734
# 3     0.00191      0.00264     0.00573  0.02309        0.327       0.01106
# 4     0.00093      0.00130     0.00278  0.01703        0.176       0.00679
#
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   sex            5875 non-null   int64
#  2   test_time      5875 non-null   float64
#  3   motor_UPDRS    5875 non-null   float64
#  4   total_UPDRS    5875 non-null   float64
#  5   Jitter(%)      5875 non-null   float64
#  6   Jitter(Abs)    5875 non-null   float64
#  7   Jitter:RAP     5875 non-null   float64
#  8   Jitter:PPQ5    5875 non-null   float64
#  9   Jitter:DDP     5875 non-null   float64
#  10  Shimmer        5875 non-null   float64
#  11  Shimmer(dB)    5875 non-null   float64
#  12  Shimmer:APQ3   5875 non-null   float64
#  13  Shimmer:APQ5   5875 non-null   float64
#  14  Shimmer:APQ11  5875 non-null   float64
#  15  Shimmer:DDA    5875 non-null   float64
#  16  NHR            5875 non-null   float64
# ...

# %%
numerical_features = X.select_dtypes(include = ['int64','float64']).columns.values
numerical_features
# Out:
# array(['subject#', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS',
#        'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5',
#        'Jitter:DDP', 'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3',
#        'Shimmer:APQ5', 'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR',
#        'RPDE', 'PPE'], dtype=object)

# %%
categorical_features = missingdata.select_dtypes(exclude = ['int64','float64']).columns.values
categorical_features
# Out:
# array([], dtype=object)

# %%
categorical_features = missingdata.select_dtypes(include = ['object']).columns.values
categorical_features
# Out:
# array([], dtype=object)

# %%
from sklearn.impute import SimpleImputer
cat_impute = SimpleImputer(strategy='constant', fill_value = 'missing')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.impute import SimpleImputer
#       2 cat_impute = SimpleImputer(strategy='constant', fill_value = 'missing')
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.3 MB 812.7 kB/s eta 0:00:11
#       --------------------------------------- 0.1/8.3 MB 1.0 MB/s eta 0:00:08
#       --------------------------------------- 0.2/8.3 MB 1.0 MB/s eta 0:00:09
#      - -------------------------------------- 0.2/8.3 MB 1.1 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/8.3 MB 1.1 MB/s eta 0:00:08
#      - -------------------------------------- 0.4/8.3 MB 1.2 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/8.3 MB 1.2 MB/s eta 0:00:07
#      -- ------------------------------------- 0.5/8.3 MB 1.2 MB/s eta 0:00:07
#      -- ------------------------------------- 0.6/8.3 MB 1.3 MB/s eta 0:00:07
#      -- ------------------------------------- 0.6/8.3 MB 1.2 MB/s eta 0:00:07
# ...

# %%
import scikit-learn as sklearn
# Out:
#   Cell In[23], line 1
#     import scikit-learn as sklearn
#                  ^
# SyntaxError: invalid syntax

# %%
import sklearn as sklearn

# %%
from sklearn.impute import SimpleImputer
cat_impute = SimpleImputer(strategy='constant', fill_value = 'missing')

# %%
X[categorical_features].head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
cat_impute.fit(X[categorical_features])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cat_impute.fit(X[categorical_features])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:390, in SimpleImputer.fit(self, X, y)
#     381 if self.verbose != "deprecated":
#     382     warnings.warn(
#     383         "The 'verbose' parameter was deprecated in version "
#     384         "1.1 and will be removed in 1.3. A warning will "
#    (...)
#     387         FutureWarning,
#     388     )
# --> 390 X = self._validate_input(X, in_fit=True)
#     392 # default fill_value is 0 for numerical input and "missing_value"
#     393 # otherwise
#     394 if self.fill_value is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:344, in SimpleImputer._validate_input(self, X, in_fit)
# ...

# %%
SimpleImputer(fill_value='missing', strategy='constant')
# Out:
# SimpleImputer(fill_value='missing', strategy='constant')

# %%
X[categorical_features] = cat_impute.transform(X[categorical_features])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 X[categorical_features] = cat_impute.transform(X[categorical_features])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:549, in SimpleImputer.transform(self, X)
# ...

# %%
X[categorical_features].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
test[categorical_features] = cat_impute.transform(test[categorical_features])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 test[categorical_features] = cat_impute.transform(test[categorical_features])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\impute\_base.py:549, in SimpleImputer.transform(self, X)
# ...

# %%
test[categorical_features].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
num_impute = SimpleImputer(strategy='median')

# %%
X[numerical_features].head()
# Out:
#    subject#  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  Jitter(Abs)  \
# 0         1    0     5.6431       28.199       34.398    0.00662     0.000034
# 1         1    0    12.6660       28.447       34.894    0.00300     0.000017
# 2         1    0    19.6810       28.695       35.389    0.00481     0.000025
# 3         1    0    25.6470       28.905       35.810    0.00528     0.000027
# 4         1    0    33.6420       29.187       36.375    0.00335     0.000020
#
#    Jitter:RAP  Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.00401      0.00317     0.01204  0.02565        0.230       0.01438
# 1     0.00132      0.00150     0.00395  0.02024        0.179       0.00994
# 2     0.00205      0.00208     0.00616  0.01675        0.181       0.00734
# 3     0.00191      0.00264     0.00573  0.02309        0.327       0.01106
# 4     0.00093      0.00130     0.00278  0.01703        0.176       0.00679
#
# ...

# %%
num_impute.fit(X[numerical_features])
# Out:
# SimpleImputer(strategy='median')

# %%
SimpleImputer(strategy='median')
# Out:
# SimpleImputer(strategy='median')

# %%
X[numerical_features] = num_impute.transform(X[numerical_features])

# %%
test[numerical_features] = num_impute.transform(test[numerical_features])

# %%
X.isnull().sum()
# Out:
# subject#         0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# PPE              0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
missingdata=pd.read_csv('parkinsons_updrs.csv.csv')

missingdata.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 missingdata=pd.read_csv('parkinsons_updrs.csv.csv')
#       3 missingdata.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
missingdata=pd.read_csv('parkinsons_updrs.csv.csv')

missingdata.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
missingdata.fillna(missingdata.mean())
# Out:
#       subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0            1   72    0     5.6431       28.199       34.398    0.00662
# 1            1   72    0    12.6660       28.447       34.894    0.00300
# 2            1   72    0    19.6810       28.695       35.389    0.00481
# 3            1   72    0    25.6470       28.905       35.810    0.00528
# 4            1   72    0    33.6420       29.187       36.375    0.00335
# ...        ...  ...  ...        ...          ...          ...        ...
# 5870        42   61    0   142.7900       22.485       33.485    0.00406
# 5871        42   61    0   149.8400       21.988       32.988    0.00297
# 5872        42   61    0   156.8200       21.495       32.495    0.00349
# 5873        42   61    0   163.7300       21.007       32.007    0.00281
# 5874        42   61    0   170.7300       20.513       31.513    0.00282
#
#       Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
missingdata.fillna(missingdata.median())
# Out:
#       subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0            1   72    0     5.6431       28.199       34.398    0.00662
# 1            1   72    0    12.6660       28.447       34.894    0.00300
# 2            1   72    0    19.6810       28.695       35.389    0.00481
# 3            1   72    0    25.6470       28.905       35.810    0.00528
# 4            1   72    0    33.6420       29.187       36.375    0.00335
# ...        ...  ...  ...        ...          ...          ...        ...
# 5870        42   61    0   142.7900       22.485       33.485    0.00406
# 5871        42   61    0   149.8400       21.988       32.988    0.00297
# 5872        42   61    0   156.8200       21.495       32.495    0.00349
# 5873        42   61    0   163.7300       21.007       32.007    0.00281
# 5874        42   61    0   170.7300       20.513       31.513    0.00282
#
#       Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
missingdata['age'] = missingdata['age'].fillna(missingdata['age'].mode()[0])

# %%
missingdata.age.mode()
# Out:
# 0    58
# Name: age, dtype: int64
